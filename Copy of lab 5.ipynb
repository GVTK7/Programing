# %%
# %%writefile p1.cpp
# #include<iostream>
# #include<stdlib.h>
# using namespace std;
#
# int main()
# {
#     int i,j,k,l,n,max_fncy,m;
#     cout<<"enter the length of the data";
#     cin>>n;
#     float a[n],sum,md;
#     sum=0;
# //taking input and adding them
#     for(m=0;m<=n-1;m++)
#     {
#
#         cin>>a[m];
#         sum=sum+a[m];
#
#     }
#     int p,q,r,mn,mi,temp,d;
# //arranging theelements in ascending order
#     for(p=0;p<=n-1;p++)
#     {
#         mn=a[p];
#         mi=p;
#         for(q=p+1;q<=n-1;q++)
#         {
#             if(a[q]<mn)
#             {
#                 mn=a[q];
#                 mi=q;
#             }
#         }
#         temp=a[p];
#         a[p]=mn;
#         a[mi]=temp;
#         cout<<a[p];
#     }
#     cout<<endl;
# //calculating median
#     if(n%2==0)
#     {
#         md=(a[n/2]+a[(n/2)-1])/2;
#     }
#     else
#     {
#         d=n/2;
#         md=a[d];
#     }
#     cout<<"median is"<<md;
#     cout<<endl;
#     cout<<"mean is"<<sum/n;
#     cout<<endl;
# //calculating the frequancies of the elements
#     int f[n]={0};//taking an array to calculate te frequancy of the input wrt their indexes
#     for (i=0;i<=n-1;i++)
#     {
#
#         for(j=i;j<=n-1;j++)
#         {
#             if (a[i]==a[j])
#             {
#                  f[i]=f[i]+1;
#             }
#         }
#         cout<<f[i];
#     }
#     cout<<endl;
#     max_fncy=f[0];
# //finding max frequancy
#     for(k=1;k<=n-1;k++)
#     {
#         if (max_fncy<f[k])
#         {
#             max_fncy=f[k];
#         }
#     }
# //printing elements with maximum frequancy
#     cout<<"mode is-";
#     for(l=0;l<=n-1;l++)
#     {
#         if(max_fncy==f[l])
#         {
#
#             cout<<a[l]<<"-";
#         }
#     }
# }

# %%
# !g++ p1.cpp
2
3
4
# !./a.out

# %%
//Given an array A of n integers, write a program to find the number of valid pairs in A. A pair (A[i], A[j]) is said to be a valid pair, if i < j and A[i] < A[j].
# %%writefile p2.cpp
#include<iostream>
#include<stdlib.h>
using namespace std;


int main()
{
    int i,j,k,n,s;
    cin>>n;
    int a[n];
    s=0;
 
    for(i=0;i<=n-1;i++)
      cin>>a[i];
 
    for(j=0;j<=n-1;j++)
    {
        for(k=j+1;k<=n-1;k++)
        {
            if(a[j]<a[k])
            {
                s=s+1;
            }
        }
    }
    cout<<s;
}

# %%
# !g++ p2.cpp
# !./a.out

# %%
//Given an array A of n integers, write a program to move all zeros in A to the end of the array. The relative order of the non-zero elements in the array should not be disturbed. For the input A ={21,0,4,0,55,0,6}, the output is {21,4,55,6,0,0,0}
# %%writefile p3.cpp
#include<iostream>
#include<stdlib.h>
using namespace std;

int main()
{
    int i,j,k,n,c,x;
    cin>>n;
    int a[n],b[n];

    for(i=0;i<=n-1;i++)
    {  
        cin>>a[i];
        b[i]=a[i];
    }
    c=0;
 
    for(j=0;j<=n-1;j++)
    {
        if(a[j]==0)
        {
            for(k=j;k<=n-2;k++)
            {
                b[k-c]=b[k-c+1];
                b[k-c+1]=0;
            }
            c=c+1;
        }
    }
    
    for(x=0;x<=n-1;x++)
      cout<<b[x]<<" ";
 
    return 0;
}

# %%
# %%writefile p1.cpp
# #include<iostream>
# #include<stdlib.h>
# using namespace std;
# // 1)Finding mean, median, mode of given numbers
#
# int main()
# {
#     int i,j,k,l,f,n,r,x;
#     cout<<"enter the length of the list";
#     cin>>n;
#     float a[n];
#     for(l=0;l<=n-1;l++)
#     {
#         cin>>a[i];
#     }
#     int b[n]={1};
#     for(i=0;i<=n-1;i++)
#     {
#         f=1
#         for(j=i+1;j<=n-1;j+=)
#         {
#             if(a[i]==a[j])
#             {
#                f=f+1;
#             }
#         }
#         b[i]=f;
#
#     }
#     m=b[0];
#     for(r=o;r<=n-1;r++)
#     {
#         if(b[r]>=m)
#         {
#             m=b[r];
#         }
#     }
#     cout>>"mode ";
#     for(x=0;x<=n-1;x++)
#     {
#         if(m==b[y])
#         {
#             cout<<a[y]<<" ,";
#         }
#     }
#     return 0;
# }
# Out:
# Overwriting p1.cpp

# %%
# !g++ p1.cpp
# !./a.out
# Out:
# p1.cpp: In function ‘int main()’:
# p1.cpp:20:9: error: expected ‘;’ before ‘for’
#          for(j=i+1;j<=n-1;j+=)
#          ^~~
# p1.cpp:20:29: error: expected primary-expression before ‘)’ token
#          for(j=i+1;j<=n-1;j+=)
#                              ^
# p1.cpp:30:5: error: ‘m’ was not declared in this scope
#      m=b[0];
#      ^
# p1.cpp:31:11: error: ‘o’ was not declared in this scope
#      for(r=o;r<=n-1;r++)
#            ^
# p1.cpp:38:9: error: no match for ‘operator>>’ (operand types are ‘std::ostream {aka std::basic_ostream<char>}’ and ‘const char [6]’)
#      cout>>"mode ";
#      ~~~~^~~~~~~~~
# In file included from /usr/include/c++/7/string:53:0,
#                  from /usr/include/c++/7/bits/locale_classes.h:40,
#                  from /usr/include/c++/7/bits/ios_base.h:41,
#                  from /usr/include/c++/7/ios:42,
#                  from /usr/include/c++/7/ostream:38,
#                  from /usr/include/c++/7/iostream:39,
# ...
