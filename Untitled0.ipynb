# %%
# %%writefile p1.ccp
#
#
# #include<iostream>
# using namespace std;
# int main()
# {
#     int a,b,z;
#     a=4;
#     b=6;
#     z=a+b;
#     cout<<z;
#  return 0;
# }
# Out:
# Overwriting p1.ccp

# %%
# %%writefile p1.cpp
# #include<iostream>
# using namespace std;
# int main()
# {
#     int n ,i ,t;
#
#     cin>>n;
#     i=1;
#
#     for(i=1;i<=10;i++)
#     {
#         t=n*i;
#         cout<<n<<"*"<<i<<"="<<t<<endl;
#
# return 0;
# }
# Out:
# Writing p1.cpp

# %%
! g++ p1.ccp
# Out:
# p1.ccp: file not recognized: File format not recognized
# collect2: error: ld returned 1 exit status

# %%
# !./a.out
